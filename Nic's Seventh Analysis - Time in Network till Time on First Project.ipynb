# %%
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio
import matplotlib.pyplot as plt
import numpy as np
conn = psycopg2.connect(
    user="ru6bjn2o1hw4oys",
    password="sPz531BWhOpWB3n8k2uo2sQ54pyHEcCnds6wodo6",
    host="evening-soiree.sequindb.com",
    database="db1np6imz7ub7rl")
query8 = """
    SELECT distinct on (experts.name)
    experts.name,
    experts.previous_status as "Status 1",
      cast(experts.created as date) as "Status 1 Date",
      selectsystems.record_id as "ID", 
      cast(selectsystems.created as date) AS "1st Project Date",
      cast(selectsystems.created as date) - cast(experts.created as date) AS "Period"
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id
      WHERE experts.previous_status like 'Available%' AND selectsystems.record_id IS NOT NULL
      ORDER BY experts.name, selectsystems.created ASC
"""
dataset8 = sqlio.read_sql_query(query8,conn)
df8 = pd.DataFrame(data=dataset8)
print(df8)
# Out:
#                          name            Status 1 Status 1 Date   ID  \
# 0              Alex Del Salto  Available for Work    2021-12-26  203
# 1             Andrea Angarica  Available for Work    2021-10-20  147
# 2               Ashley Rector  Available for Work    2021-08-23  134
# 3              Avery Rizzotto  Available for Work    2021-08-03  108
# 4                Betsy Wecker  Available for Work    2021-02-11    3
# 5              Bryan Driscoll  Available for Work    2021-02-11   12
# 6           Dylan Hildebrandt  Available for Work    2021-07-12  136
# 7               Eugene Slyman  Available for Work    2021-08-02   90
# 8                Evan Somano   Available for Work    2021-03-30   49
# 9            Grafton Robinson  Available for Work    2021-03-02   22
# 10  Jessica "Jessie" Thompson  Available for Work    2021-07-26   83
# 11                   John Kim  Available for Work    2021-03-01   21
# 12             Klarrisa Arafa  Available for Work    2021-06-25   77
# 13  Margaret "Maggie" Marsico  Available for Work    2021-06-11   93
# 14               Molly Carter  Available for Work    2021-07-13   82
# 15         Oh Brother Digital  Available for Work    2021-02-11    6
# 16             Peter Matchett  Available for Work    2021-06-15   55
# 17                Richard Pyo  Available for Work    2021-07-12  114
# 18             Rita Gutkovich  Available for Work    2021-02-11    8
# 19             Steve Cicalese  Available for Work    2021-03-22   34
#
#    1st Project Date  Period
# 0        2022-05-09     134
# 1        2021-12-10      51
# 2        2021-11-17      86
# 3        2021-09-29      57
# 4        2021-02-17       6
# 5        2021-02-18       7
# 6        2021-11-18     129
# 7        2021-08-27      25
# 8        2021-07-02      94
# 9        2021-03-02       0
# 10       2021-08-27      32
# 11       2021-03-02       1
# 12       2021-08-27      63
# 13       2021-08-27      77
# 14       2021-08-27      45
# 15       2021-02-17       6
# 16       2021-07-02      17
# 17       2021-10-08      88
# 18       2021-02-17       6
# 19       2021-03-22       0

# %%
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio
import matplotlib.pyplot as plt
import numpy as np
conn = psycopg2.connect(
    user="ru6bjn2o1hw4oys",
    password="sPz531BWhOpWB3n8k2uo2sQ54pyHEcCnds6wodo6",
    host="evening-soiree.sequindb.com",
    database="db1np6imz7ub7rl")
query9 = """
    SELECT distinct on (experts.name)
    experts.name,
    experts.status as "Status 2",
      cast(experts.status_last_modified as date) AS "Status 2 Date",
      selectsystems.record_id as "ID", 
      cast(selectsystems.created as date) AS "1st Project Date",
      cast(selectsystems.created as date) - cast(experts.status_last_modified as date) AS "Period"    
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id
      WHERE experts.status like 'Available%' AND selectsystems.record_id IS NOT NULL AND cast(experts.status_last_modified as date) < cast(selectsystems.created as date) 
      ORDER BY experts.name, selectsystems.created ASC
"""
dataset9 = sqlio.read_sql_query(query9,conn)
df9 = pd.DataFrame(data=dataset9)
print(df9)
# Out:
#                                    name            Status 2 Status 2 Date  \
# 0             Alexandra (Alex) Campbell  Available for Work    2021-08-24
# 1                          Alex Arevalo  Available for Work    2021-11-17
# 2                         Amelie Pollak  Available for Work    2022-05-25
# 3            Amy Hage & Brittney Trahan  Available for Work    2021-08-26
# 4                            Andrea Sok  Available for Work    2021-11-11
# 5                            Avi Afriat  Available for Work    2022-04-15
# 6                           Ben Zettler  Available for Work    2021-09-01
# 7        Bon Ishimori (Powerful Impact)  Available for Work    2022-04-25
# 8                        Brenton Thomas  Available for Work    2021-09-08
# 9                       Cameron Cummins  Available for Work    2021-09-28
# 10                       Carrie Solomon  Available for Work    2021-07-29
# 11                     Christina Warner  Available for Work    2022-02-14
# 12                     Ciaraleaf Meaney  Available for Work    2022-02-14
# 13                      Danielle Hughes  Available for Work    2021-09-28
# 14                     Danielle Kochavy  Available for Work    2021-07-15
# 15                         Daniel Royer  Available for Work    2021-04-21
# 16                      Drew Blumenthal  Available for Work    2022-04-26
# 17                         Eric Brekher  Available for Work    2021-10-27
# 18                       Eric Westerman  Available for Work    2021-03-02
# 19                              Fei Nie  Available for Work    2021-07-22
# 20                     Gabrielle Graham  Available for Work    2022-03-08
# 21                        Gabriel Swain  Available for Work    2022-04-29
# 22                      Garrett Mireles  Available for Work    2021-08-02
# 23                    Geraldine Orentas  Available for Work    2021-07-15
# 24    Gurvinder Singh (Powerful Impact)  Available for Work    2022-04-25
# 25                      Henry Hernandez  Available for Work    2021-09-08
# 26                          Jason Yates  Available for Work    2021-09-01
# 27                  Joseph McLean Lusby  Available for Work    2021-08-02
# 28                          Joseph Pino  Available for Work    2022-04-15
# 29                         Julee Foster  Available for Work    2021-09-08
# 30                       Justin Adelson  Available for Work    2022-03-08
# 31       Kanwar Uppal (Powerful Impact)  Available for Work    2022-04-25
# 32                      Kayla Perlstein  Available for Work    2022-01-19
# 33  Laraleigh Ruzicka (Powerful Impact)  Available for Work    2022-04-25
# 34                     Larell Scardelli  Available for Work    2021-09-08
# 35                    Madison Bracaglia  Available for Work    2021-07-15
# 36        Mafe Aclado (Powerful Impact)  Available for Work    2022-04-25
# 37                      Maggie Valiunas  Available for Work    2022-03-08
# 38                            Major Oni  Available for Work    2022-04-12
# 39                      Makenna Nielsen  Available for Work    2021-09-01
# 40            Maksym "Max" Lopushynskyi  Available for Work    2021-11-03
# 41                        Mary Mitchell  Available for Work    2022-03-08
# 42                     Matthew Proffitt  Available for Work    2021-10-29
# 43                 Meagan "Meg" Thrower  Available for Work    2021-07-02
# 44                    Meredith Gernigin  Available for Work    2022-01-20
# 45                  Michael Antonicelli  Available for Work    2021-08-24
# 46                   Michelle Roopchand  Available for Work    2022-01-21
# 47                        Mysty Stewart  Available for Work    2021-10-18
# 48                         Nate Saienni  Available for Work    2022-03-08
# 49         Nick Young (Marketplace Ops)  Available for Work    2022-05-09
# 50                         Robert Hanes  Available for Work    2022-04-29
# 51                         Ryan Bennion  Available for Work    2021-09-09
# 52                      Shane McCloskey  Available for Work    2022-03-25
# 53                    Tatyana Litvinova  Available for Work    2021-11-24
# 54                      Terry Schilling  Available for Work    2021-05-05
# 55           Theodore "Teddy" Stavetski  Available for Work    2021-08-03
# 56                William Brandon Bales  Available for Work    2021-07-28
#
#      ID 1st Project Date  Period
# 0   161       2022-02-04     164
# 1   144       2021-12-07      20
# 2   236       2022-06-08      14
# 3   106       2021-09-15      20
# 4   168       2022-02-15      96
# 5   197       2022-05-02      17
# 6   117       2021-10-19      48
# 7   224       2022-05-25      30
# 8   122       2021-10-19      41
# 9   198       2022-05-03     217
# 10  233       2022-05-31     306
# 11  218       2022-05-23      98
# 12  166       2022-02-15       1
# 13  201       2022-05-04     218
# 14   60       2021-07-21       6
# 15  190       2022-04-05     349
# 16  208       2022-05-11      15
# 17  159       2022-02-02      98
# 18  217       2022-05-20     444
# 19   81       2021-08-27      36
# 20  232       2022-05-27      80
# 21  213       2022-05-18      19
# 22  138       2021-11-29     119
# 23  204       2022-05-10     299
# 24  225       2022-05-25      30
# 25  181       2022-03-16     189
# 26  183       2022-03-16     196
# 27  239       2022-06-13     315
# 28  238       2022-06-13      59
# 29  179       2022-03-08     181
# 30  231       2022-05-26      79
# 31  227       2022-05-25      30
# 32  195       2022-05-02     103
# 33  228       2022-05-25      30
# 34  137       2021-11-18      71
# 35   75       2021-08-27      43
# 36  226       2022-05-25      30
# 37  209       2022-05-11      64
# 38  205       2022-05-10      28
# 39  141       2021-11-29      89
# 40  131       2021-11-16      13
# 41  212       2022-05-17      70
# 42  132       2021-11-17      19
# 43   64       2021-08-12      41
# 44  207       2022-05-10     110
# 45  130       2021-11-16      84
# 46  169       2022-02-25      35
# 47  152       2022-01-18      92
# 48  184       2022-03-22      14
# 49  235       2022-06-01      23
# 50  219       2022-05-23      24
# 51  129       2021-11-12      64
# 52  229       2022-05-26      62
# 53  145       2021-12-10      16
# 54   91       2021-08-27     114
# 55   95       2021-08-27      24
# 56   84       2021-08-27      30

# %%
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio
import matplotlib.pyplot as plt
import numpy as np
conn = psycopg2.connect(
    user="ru6bjn2o1hw4oys",
    password="sPz531BWhOpWB3n8k2uo2sQ54pyHEcCnds6wodo6",
    host="evening-soiree.sequindb.com",
    database="db1np6imz7ub7rl")
query10 = """
    SELECT distinct on (experts.name)
    experts.name AS "Name",
    experts.previous_status as "Status",
      cast(experts.created as date) as "Status Date",
      selectsystems.record_id as "ID", 
      cast(selectsystems.created as date) AS "1st Project Date",
      cast(selectsystems.created as date) - cast(experts.created as date) AS "Period"
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id
      WHERE experts.previous_status like 'Available%' AND selectsystems.record_id IS NOT NULL

      UNION 
      SELECT distinct on (experts.name)
    experts.name AS "Name",
    experts.status as "Status",
      cast(experts.status_last_modified as date) AS "Status Date",
      selectsystems.record_id as "ID", 
      cast(selectsystems.created as date) AS "1st Project Date",
      cast(selectsystems.created as date) - cast(experts.status_last_modified as date) AS "Period"    
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id
      WHERE experts.status like 'Available%' AND selectsystems.record_id IS NOT NULL AND cast(experts.status_last_modified as date) < cast(selectsystems.created as date) 

"""
dataset10 = sqlio.read_sql_query(query10,conn)
df10 = pd.DataFrame(data=dataset10)
print(df10)
# Out:
#                               Name              Status Status Date   ID  \
# 0                     Robert Hanes  Available for Work  2022-04-29  219
# 1   Bon Ishimori (Powerful Impact)  Available for Work  2022-04-25  224
# 2        Maksym "Max" Lopushynskyi  Available for Work  2021-11-03  176
# 3                     Molly Carter  Available for Work  2021-07-13   82
# 4                Dylan Hildebrandt  Available for Work  2021-07-12  136
# ..                             ...                 ...         ...  ...
# 72                 Andrea Angarica  Available for Work  2021-10-20  147
# 73            Meagan "Meg" Thrower  Available for Work  2021-07-02   64
# 74      Amy Hage & Brittney Trahan  Available for Work  2021-08-26  106
# 75               Tatyana Litvinova  Available for Work  2021-11-24  145
# 76       Margaret "Maggie" Marsico  Available for Work  2021-06-11   93
#
#    1st Project Date  Period
# 0        2022-05-23      24
# 1        2022-05-25      30
# 2        2022-03-08     125
# 3        2021-08-27      45
# 4        2021-11-18     129
# ..              ...     ...
# 72       2021-12-10      51
# 73       2021-08-12      41
# 74       2021-09-15      20
# 75       2021-12-10      16
# 76       2021-08-27      77
#
# [77 rows x 6 columns]

# %%
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio
import matplotlib.pyplot as plt
import numpy as np
conn = psycopg2.connect(
    user="ru6bjn2o1hw4oys",
    password="sPz531BWhOpWB3n8k2uo2sQ54pyHEcCnds6wodo6",
    host="evening-soiree.sequindb.com",
    database="db1np6imz7ub7rl")
query11 = """
    
    WITH status_2 AS
    (SELECT distinct on (experts.name)
    experts.name as "Name",
    experts.status as "Status",
      cast(experts.status_last_modified as date) AS "Status Date",
      selectsystems.record_id as "ID", 
      cast(selectsystems.created as date) AS "1st Project Date",
      cast(selectsystems.created as date) - cast(experts.status_last_modified as date) AS "Period"    
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id
      WHERE experts.status like 'Available%' AND selectsystems.record_id IS NOT NULL AND cast(experts.status_last_modified as date) < cast(selectsystems.created as date) 
      ORDER BY experts.name, selectsystems.created ASC)
      
      , status_1 AS 
    (SELECT distinct on (experts.name)
    experts.name as "Name",
    experts.previous_status as "Status",
      cast(experts.created as date) as "Status Date",
      selectsystems.record_id as "ID", 
      cast(selectsystems.created as date) AS "1st Project Date",
      cast(selectsystems.created as date) - cast(experts.created as date) AS "Period"
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id
      WHERE experts.previous_status like 'Available%' AND selectsystems.record_id IS NOT NULL
      ORDER BY experts.name, selectsystems.created ASC)

SELECT * from status_1

UNION

SELECT * from status_2

"""
dataset11 = sqlio.read_sql_query(query11,conn)
df11 = pd.DataFrame(data=dataset11)
print(df11)
# Out:
#                               Name              Status Status Date   ID  \
# 0                     Robert Hanes  Available for Work  2022-04-29  219
# 1   Bon Ishimori (Powerful Impact)  Available for Work  2022-04-25  224
# 2                     Molly Carter  Available for Work  2021-07-13   82
# 3                     Evan Somano   Available for Work  2021-03-30   49
# 4                Dylan Hildebrandt  Available for Work  2021-07-12  136
# ..                             ...                 ...         ...  ...
# 72            Meagan "Meg" Thrower  Available for Work  2021-07-02   64
# 73      Amy Hage & Brittney Trahan  Available for Work  2021-08-26  106
# 74               Tatyana Litvinova  Available for Work  2021-11-24  145
# 75                    Alex Arevalo  Available for Work  2021-11-17  144
# 76       Margaret "Maggie" Marsico  Available for Work  2021-06-11   93
#
#    1st Project Date  Period
# 0        2022-05-23      24
# 1        2022-05-25      30
# 2        2021-08-27      45
# 3        2021-07-02      94
# 4        2021-11-18     129
# ..              ...     ...
# 72       2021-08-12      41
# 73       2021-09-15      20
# 74       2021-12-10      16
# 75       2021-12-07      20
# 76       2021-08-27      77
#
# [77 rows x 6 columns]

# %%
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio
import matplotlib.pyplot as plt
import numpy as np
conn = psycopg2.connect(
    user="ru6bjn2o1hw4oys",
    password="sPz531BWhOpWB3n8k2uo2sQ54pyHEcCnds6wodo6",
    host="evening-soiree.sequindb.com",
    database="db1np6imz7ub7rl")
query11 = """
    
    WITH status_2 AS
    (SELECT distinct on (experts.name)
    experts.name as "Name",
    experts.status as "Status",
      cast(experts.status_last_modified as date) AS "Status Date",
      selectsystems.record_id as "ID", 
      cast(selectsystems.created as date) AS "1st Project Date",
      cast(selectsystems.created as date) - cast(experts.status_last_modified as date) AS "Period"    
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id
      WHERE experts.status like 'Available%' AND selectsystems.record_id IS NOT NULL AND cast(experts.status_last_modified as date) < cast(selectsystems.created as date) 
      ORDER BY experts.name, selectsystems.created ASC)
      
      , status_1 AS 
    (SELECT distinct on (experts.name)
    experts.name as "Name",
    experts.previous_status as "Status",
      cast(experts.created as date) as "Status Date",
      selectsystems.record_id as "ID", 
      cast(selectsystems.created as date) AS "1st Project Date",
      cast(selectsystems.created as date) - cast(experts.created as date) AS "Period"
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id
      WHERE experts.previous_status like 'Available%' AND selectsystems.record_id IS NOT NULL
      ORDER BY experts.name, selectsystems.created ASC)

      , combined AS 
      (SELECT * from status_1 UNION SELECT * from status_2)
      

SELECT cast(case when "combined"."Period" >= 0 and "combined"."Period" <= 30    then '  1'
            when "combined"."Period" > 30 and "combined"."Period" <= 60   then ' 2'
            when "combined"."Period" > 60 and "combined"."Period" <= 90  then ' 3'
            when "combined"."Period" > 90 and "combined"."Period" <= 120   then ' 4'
            when "combined"."Period" > 120 and "combined"."Period" <= 150  then ' 5'
            when "combined"."Period" > 150 and "combined"."Period" <= 180  then ' 6'
            when "combined"."Period" > 180 and "combined"."Period" <= 210    then ' 7'
            when "combined"."Period" > 210 and "combined"."Period" <= 240   then ' 8'
            when "combined"."Period" > 240 and "combined"."Period" <= 270  then ' 9'
            when "combined"."Period" > 270 and "combined"."Period" <= 300   then ' 10'
            when "combined"."Period" > 300 and "combined"."Period" <= 330  then ' 11'
            when "combined"."Period" > 330 and "combined"."Period" <= 365  then ' 12'
            else '13' end as integer) as "Monthly Period",
            count(*) as "Number of Experts"
            FROM combined
            GROUP BY 1

"""
dataset11 = sqlio.read_sql_query(query11,conn)
df11 = pd.DataFrame(data=dataset11)
print(df11)
# Out:
#     Monthly Period  Number of Experts
# 0                1                 31
# 1                2                 11
# 2                3                 13
# 3                4                  9
# 4                5                  2
# 5                6                  1
# 6                7                  3
# 7                8                  2
# 8               10                  1
# 9               11                  2
# 10              12                  1
# 11              13                  1

# %%
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio
import matplotlib.pyplot as plt
import numpy as np
conn = psycopg2.connect(
    user="ru6bjn2o1hw4oys",
    password="sPz531BWhOpWB3n8k2uo2sQ54pyHEcCnds6wodo6",
    host="evening-soiree.sequindb.com",
    database="db1np6imz7ub7rl")
query11 = """
    
    WITH status_2 AS
    (SELECT distinct on (experts.name)
    experts.name as "Name",
    experts.status as "Status",
      cast(experts.status_last_modified as date) AS "Status Date",
      selectsystems.record_id as "ID", 
      cast(selectsystems.created as date) AS "1st Project Date",
      cast(selectsystems.created as date) - cast(experts.status_last_modified as date) AS "Period"    
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id
      WHERE experts.status like 'Available%' AND selectsystems.record_id IS NOT NULL AND cast(experts.status_last_modified as date) < cast(selectsystems.created as date) 
      ORDER BY experts.name, selectsystems.created ASC)
      
      , status_1 AS 
    (SELECT distinct on (experts.name)
    experts.name as "Name",
    experts.previous_status as "Status",
      cast(experts.created as date) as "Status Date",
      selectsystems.record_id as "ID", 
      cast(selectsystems.created as date) AS "1st Project Date",
      cast(selectsystems.created as date) - cast(experts.created as date) AS "Period"
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id
      WHERE experts.previous_status like 'Available%' AND selectsystems.record_id IS NOT NULL
      ORDER BY experts.name, selectsystems.created ASC)

      , combined AS 
      (SELECT * from status_1 UNION SELECT * from status_2)
      

SELECT cast(case when "combined"."Period" >= 0 and "combined"."Period" <= 30    then '  1'
            when "combined"."Period" > 30 and "combined"."Period" <= 60   then ' 2'
            when "combined"."Period" > 60 and "combined"."Period" <= 90  then ' 3'
            when "combined"."Period" > 90 and "combined"."Period" <= 120   then ' 4'
            when "combined"."Period" > 120 and "combined"."Period" <= 150  then ' 5'
            when "combined"."Period" > 150 and "combined"."Period" <= 180  then ' 6'
            when "combined"."Period" > 180 and "combined"."Period" <= 210    then ' 7'
            when "combined"."Period" > 210 and "combined"."Period" <= 240   then ' 8'
            when "combined"."Period" > 240 and "combined"."Period" <= 270  then ' 9'
            when "combined"."Period" > 270 and "combined"."Period" <= 300   then ' 10'
            when "combined"."Period" > 300 and "combined"."Period" <= 330  then ' 11'
            when "combined"."Period" > 330 and "combined"."Period" <= 365  then ' 12'
            else '13' end as integer) as "Period in Months",
            count(*) as "Number of Experts"
            FROM combined
            GROUP BY 1

"""
dataset11 = sqlio.read_sql_query(query11,conn)
df11 = pd.DataFrame(data=dataset11)
print(df11)

# Define Data
xdata=df11['Period in Months']
ydata=df11['Number of Experts']
y_error=2
    
# Plot
plt.figure(figsize=(15, 7))
plt.bar(xdata,ydata, color ='maroon',width = 0.98)
plt.plot(xdata, ydata, 'o', linestyle = 'dotted', color ='black', linewidth=2)
plt.title("Time In Network to Time on First Project - Data Analysis Prepared by Nic Rayce")
plt.xlabel('Period (in Months)')
plt.ylabel('Count of Active Experts')
ax = plt.subplot()
ax.grid(color='grey', linestyle='dashed', linewidth=0.5)
plt.show()
# Out:
#     Period in Months  Number of Experts
# 0                  1                 31
# 1                  2                 11
# 2                  3                 13
# 3                  4                  9
# 4                  5                  2
# 5                  6                  1
# 6                  7                  3
# 7                  8                  2
# 8                 10                  1
# 9                 11                  2
# 10                12                  1
# 11                13                  1

# %%
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio
import matplotlib.pyplot as plt
import numpy as np
conn = psycopg2.connect(
    user="ru6bjn2o1hw4oys",
    password="sPz531BWhOpWB3n8k2uo2sQ54pyHEcCnds6wodo6",
    host="evening-soiree.sequindb.com",
    database="db1np6imz7ub7rl")
query7 = """
    SELECT 
    cast((CASE WHEN "source"."ID" IS NOT NULL THEN 1 ELSE 0 END) as float) AS "Job ID Exists & More Than 30", 
    "source"."ID",
    "source"."Registration Date",
    "source"."Job Onboarding Date",
    "source"."Period"
  FROM
(SELECT 
      selectsystems.record_id as "ID", 
      experts.name,
      cast (experts.created as date) as "Registration Date",
      selectsystems.created as "Job Onboarding Date",
      cast(selectsystems.created as date) - cast(experts.created as date) as "Period"
    FROM 
    experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id)"source"
      ORDER BY "source"."Registration Date"
      """
dataset7 = sqlio.read_sql_query(query7,conn)
df7 = pd.DataFrame(data=dataset7)
df7.to_csv('analysis7_morethan30days.csv')
print(df7)
# Out:
#      Job ID Exists & More Than 30    ID Registration Date Job Onboarding Date  \
# 0                             1.0   6.0        2021-02-11          2021-02-17
# 1                             1.0  51.0        2021-02-11          2021-07-02
# 2                             1.0  43.0        2021-02-11          2021-05-20
# 3                             1.0  97.0        2021-02-11          2021-08-31
# 4                             1.0  32.0        2021-02-11          2021-03-16
# ..                            ...   ...               ...                 ...
# 753                           0.0   NaN        2022-06-08                 NaT
# 754                           0.0   NaN        2022-06-08                 NaT
# 755                           0.0   NaN        2022-06-09                 NaT
# 756                           0.0   NaN        2022-06-11                 NaT
# 757                           0.0   NaN        2022-06-13                 NaT
#
#      Period
# 0       6.0
# 1     141.0
# 2      98.0
# 3     201.0
# 4      33.0
# ..      ...
# 753     NaN
# 754     NaN
# 755     NaN
# 756     NaN
# 757     NaN
#
# [758 rows x 5 columns]

# %%
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio
import matplotlib.pyplot as plt
import numpy as np
conn = psycopg2.connect(
    user="ru6bjn2o1hw4oys",
    password="sPz531BWhOpWB3n8k2uo2sQ54pyHEcCnds6wodo6",
    host="evening-soiree.sequindb.com",
    database="db1np6imz7ub7rl")
query5 = """
    SELECT 
  cast(
    sum(
      CASE WHEN "source"."ID" IS NOT NULL THEN 1 ELSE 0 END
    ) as float
  ) / count(*) * 100 AS "Percentage of Active Experts - ALL" , date_trunc('month', cast("source"."Date" as date)) as "Registration Month"
  FROM 
    (SELECT 
      selectsystems.record_id as "ID", 
      experts.name,
      experts.created as "Date"
    FROM 
      experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id)"source"
      GROUP BY date_trunc('month', cast("source"."Date" as date))
      ORDER BY date_trunc('month', cast("source"."Date" as date)) DESC
      """
dataset5 = sqlio.read_sql_query(query5,conn)
df5 = pd.DataFrame(data=dataset5)
print(df5)

query6 = """
    SELECT 
    cast(sum(CASE WHEN "source"."ID" IS NOT NULL AND 
    "source"."Period" <= 30 THEN 1 ELSE 0 END) as float) / count (*) * 100 AS "Percentage of Active Experts within 30 Days", 
    date_trunc('month', "source"."Registration Date") as "Registration Month"
  FROM
(SELECT 
      selectsystems.record_id as "ID", 
      experts.name,
      cast (experts.created as date) as "Registration Date",
      selectsystems.created as "Job Onboarding Date",
      cast(selectsystems.created as date) - cast(experts.created as date) as "Period"
    FROM 
    experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id)"source"
      GROUP BY date_trunc('month', "source"."Registration Date")
      ORDER BY date_trunc('month', "source"."Registration Date") DESC
      """
dataset6 = sqlio.read_sql_query(query6,conn)
df6 = pd.DataFrame(data=dataset6)
print(df6)

query7 = """
    SELECT 
    cast(sum(CASE WHEN "source"."ID" IS NOT NULL AND 
    "source"."Period" <= 90 THEN 1 ELSE 0 END) as float) / count (*) * 100 AS "Percentage of Active Experts within 90 Days", 
    date_trunc('month', "source"."Registration Date") as "Registration Month"
  FROM
(SELECT 
      selectsystems.record_id as "ID", 
      experts.name,
      cast (experts.created as date) as "Registration Date",
      selectsystems.created as "Job Onboarding Date",
      cast(selectsystems.created as date) - cast(experts.created as date) as "Period"
    FROM 
    experts 
      LEFT JOIN selectsystems 
      ON selectsystems.expert = experts.id)"source"
      GROUP BY date_trunc('month', "source"."Registration Date")
      ORDER BY date_trunc('month', "source"."Registration Date") DESC
      """
dataset7 = sqlio.read_sql_query(query7,conn)
df7 = pd.DataFrame(data=dataset7)
print(df7)


# Define Data
xdata1=df5['Registration Month']
ydata1=df5['Percentage of Active Experts - ALL']
xdata2=df7['Registration Month']
ydata2=df7['Percentage of Active Experts within 90 Days']
xdata3=df6['Registration Month']
ydata3=df6['Percentage of Active Experts within 30 Days']

    
# Plot
plt.figure(figsize=(15, 7))
plt.plot(xdata1, ydata1, 'o', linestyle = 'dotted', linewidth=2)
plt.plot(xdata2, ydata2, 'o', linestyle = 'dotted', linewidth=2)
plt.plot(xdata3, ydata3, 'o', linestyle = 'dotted', linewidth=2)
plt.legend(['Active Experts Who Get A Job Within 180 Days', 'Active Experts Who Get A Job Within 90 Days' ,'Active Experts Who Get A Job Within 30 Days'])
plt.title("Percentage of Active Experts MoM - Data Analysis Prepared by Nic Rayce")
plt.xlabel('Registration Date')
plt.ylabel('Percentage of Active Experts')
ax = plt.subplot()
ax.grid(color='grey', linestyle='dashed', linewidth=0.5)

plt.show()
# Out:
#     Percentage of Active Experts - ALL        Registration Month
# 0                             0.000000 2022-06-01 00:00:00+00:00
# 1                             6.451613 2022-05-01 00:00:00+00:00
# 2                            18.032787 2022-04-01 00:00:00+00:00
# 3                             8.000000 2022-03-01 00:00:00+00:00
# 4                             7.692308 2022-02-01 00:00:00+00:00
# 5                            10.526316 2022-01-01 00:00:00+00:00
# 6                             2.380952 2021-12-01 00:00:00+00:00
# 7                            10.526316 2021-11-01 00:00:00+00:00
# 8                            23.076923 2021-10-01 00:00:00+00:00
# 9                            12.195122 2021-09-01 00:00:00+00:00
# 10                           27.500000 2021-08-01 00:00:00+00:00
# 11                           17.000000 2021-07-01 00:00:00+00:00
# 12                           53.333333 2021-06-01 00:00:00+00:00
# 13                           58.333333 2021-05-01 00:00:00+00:00
# 14                           62.500000 2021-04-01 00:00:00+00:00
# 15                           54.945055 2021-03-01 00:00:00+00:00
# 16                           72.500000 2021-02-01 00:00:00+00:00
#     Percentage of Active Experts within 30 Days        Registration Month
# 0                                      0.000000 2022-06-01 00:00:00+00:00
# 1                                      6.451613 2022-05-01 00:00:00+00:00
# 2                                      6.557377 2022-04-01 00:00:00+00:00
# 3                                      0.000000 2022-03-01 00:00:00+00:00
# 4                                      3.846154 2022-02-01 00:00:00+00:00
# 5                                      0.000000 2022-01-01 00:00:00+00:00
# 6                                      0.000000 2021-12-01 00:00:00+00:00
# 7                                      5.263158 2021-11-01 00:00:00+00:00
# 8                                      1.923077 2021-10-01 00:00:00+00:00
# 9                                      0.000000 2021-09-01 00:00:00+00:00
# 10                                     2.500000 2021-08-01 00:00:00+00:00
# 11                                     4.000000 2021-07-01 00:00:00+00:00
# 12                                     3.333333 2021-06-01 00:00:00+00:00
# 13                                     4.166667 2021-05-01 00:00:00+00:00
# 14                                     0.000000 2021-04-01 00:00:00+00:00
# 15                                    15.384615 2021-03-01 00:00:00+00:00
# 16                                    35.000000 2021-02-01 00:00:00+00:00
#     Percentage of Active Experts within 90 Days        Registration Month
# 0                                      0.000000 2022-06-01 00:00:00+00:00
# 1                                      6.451613 2022-05-01 00:00:00+00:00
# 2                                     18.032787 2022-04-01 00:00:00+00:00
# 3                                      8.000000 2022-03-01 00:00:00+00:00
# 4                                      3.846154 2022-02-01 00:00:00+00:00
# 5                                      5.263158 2022-01-01 00:00:00+00:00
# 6                                      0.000000 2021-12-01 00:00:00+00:00
# 7                                      7.017544 2021-11-01 00:00:00+00:00
# 8                                      7.692308 2021-10-01 00:00:00+00:00
# 9                                      2.439024 2021-09-01 00:00:00+00:00
# 10                                     8.750000 2021-08-01 00:00:00+00:00
# 11                                     9.000000 2021-07-01 00:00:00+00:00
# 12                                    30.000000 2021-06-01 00:00:00+00:00
# 13                                    12.500000 2021-05-01 00:00:00+00:00
# 14                                     0.000000 2021-04-01 00:00:00+00:00
# 15                                    19.780220 2021-03-01 00:00:00+00:00
# 16                                    40.000000 2021-02-01 00:00:00+00:00
